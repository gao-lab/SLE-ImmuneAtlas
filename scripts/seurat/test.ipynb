# %%
library(Seurat)
# Out:
# Attaching SeuratObject

# %%
load('../../output_file/seurat/t_cell/tcell_harmony_anno.rdata')

# %%
t_yd_marker <- c('TRDV1','TRDV2','TRGV9')
t_MAIT_marker <- c('TRAV1-2','TRAJ33','TRAJ20','TRAJ12')
t_invarient_NKT_marker <- c('TRAV10','TRAJ18','CD1D')
t_rare_marker <- c(t_yd_marker,t_MAIT_marker,t_invarient_NKT_marker)

# %%
options(repr.plot.width=10, repr.plot.height=8)
VlnPlot(tcell, features = t_MAIT_marker, group.by = 'seurat_clusters', ncol = 2)
# Out:
# plot without title

# %%
VlnPlot(tcell, features = t_yd_marker, group.by = 'seurat_clusters', ncol = 2)
# Out:
# plot without title

# %%
DimPlot(tcell,group.by = 'seurat_clusters',label = T
    )
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
ls()
# Out:
# character(0)
