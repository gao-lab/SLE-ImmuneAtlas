# %% [markdown]
# ## 测试
# 用plasma 数据来测试conga的运行以及分析步骤

# %%
# import conga
import pandas as pd

# %%
test = pd.read_table('../../cellphonedb/cellphonedb_count.txt')

# %%
test_1 = test.iloc[:,1:]

# %%
test_1.set_index('V1',inplace=True)

# %%
test_1
# Out:
#             AAACCTGTCCATGCTC-1_1  AAACGGGTCCCATTAT-1_1  AAAGATGTCACCTTAT-1_1  \
# V1
# AL627309.1                     0                     0                     0
# AL627309.5                     0                     0                     0
# LINC01409                      0                     0                     0
# FAM87B                         0                     0                     0
# LINC01128                      0                     0                     0
# ...                          ...                   ...                   ...
# LINC01723                      0                     0                     0
# LINC01666                      0                     0                     0
# PLEKHG4B                       0                     0                     0
# AC100801.2                     0                     0                     0
# LINC01446                      0                     0                     0
#
# ...

# %%
test_1.to_csv('../../cellphonedb/cellphonedb_count_pandas.txt',sep='\t')
